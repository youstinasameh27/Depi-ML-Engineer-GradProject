# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip uninstall -y pillow torchvision
# !pip install pillow==9.5.0 torchvision==0.15.2
# !pip install facenet-pytorch
import os; os.kill(os.getpid(), 9)  # force restart

# %%
import hashlib
import shutil
from pathlib import Path
from PIL import Image
from tqdm.notebook import tqdm
import torch
from torchvision import transforms
from facenet_pytorch import MTCNN
from sklearn.model_selection import train_test_split
import os

# Correct dataset root path based on paste.txt
base_dir = '/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled'
processed_dir = '/kaggle/working/processed_faces'
train_dir = '/kaggle/working/data_split/train'
val_dir = '/kaggle/working/data_split/val'
val_split = 0.2

device = 'cuda' if torch.cuda.is_available() else 'cpu'
mtcnn = MTCNN(image_size=160, margin=10, min_face_size=10, device=device)

augment = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
])

shutil.rmtree(processed_dir, ignore_errors=True)
os.makedirs(processed_dir, exist_ok=True)

# Test face detection on sample image to verify correct paths and model working
def test_face_detection(image_path):
    img = Image.open(image_path).convert('RGB')
    boxes, probs = mtcnn.detect(img)
    print(f"Detected boxes for {image_path}: {boxes}")

test_face_detection('/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/Aaron_Eckhart/Aaron_Eckhart_0001.jpg')

# Step 1: Detect, crop, align faces, save
def save_faces(data_dir, save_dir):
    image_paths = list(Path(data_dir).rglob('*.jpg'))
    for img_path in tqdm(image_paths, desc="Processing images"):
        person_name = img_path.parent.name
        save_person_dir = Path(save_dir) / person_name
        save_person_dir.mkdir(parents=True, exist_ok=True)
        try:
            img = Image.open(img_path).convert('RGB')
            face = mtcnn(img)
            if face is not None:
                face_img = transforms.ToPILImage()(face)
                dst_path = save_person_dir / img_path.name
                face_img.save(dst_path)
                print(f"Saved face to {dst_path}")
            else:
                print(f"No face detected in {img_path}")
        except Exception as e:
            print(f"Error processing {img_path}: {e}")
            continue

save_faces(base_dir, processed_dir)

num_processed = sum(1 for _ in Path(processed_dir).rglob('*.jpg'))
print(f"Number of processed face images: {num_processed}")

# Step 2: Augmentation
def augment_faces(src_dir, num_aug=2):
    for person_dir in Path(src_dir).iterdir():
        for img_path in person_dir.glob('*.jpg'):
            img = Image.open(img_path)
            for i in range(num_aug):
                img_aug = augment(img)
                save_aug_dir = Path(src_dir) / person_dir.name
                save_aug_dir.mkdir(parents=True, exist_ok=True)
                img_aug.save(save_aug_dir / f"{img_path.stem}_aug{i}{img_path.suffix}")

augment_faces(processed_dir)

# Step 3: Remove duplicates
def remove_duplicates(folder):
    seen_hashes = set()
    num_removed = 0
    for person_dir in Path(folder).iterdir():
        if not person_dir.is_dir():
            continue
        for img_path in list(person_dir.glob('*.jpg')):
            with open(img_path, 'rb') as f:
                filehash = hashlib.md5(f.read()).hexdigest()
            if filehash in seen_hashes:
                img_path.unlink()
                num_removed += 1
            else:
                seen_hashes.add(filehash)
    print(f"Removed {num_removed} duplicate images.")

remove_duplicates(processed_dir)

# Step 4: Train/val split
def split_train_val(src_dir, train_dir, val_dir, val_split=0.2):
    for person_dir in Path(src_dir).iterdir():
        img_paths = list(person_dir.glob('*.jpg'))
        if len(img_paths) < 2:
            continue
        train_imgs, val_imgs = train_test_split(img_paths, test_size=val_split, random_state=42)
        for t in train_imgs:
            out_dir = Path(train_dir) / person_dir.name
            out_dir.mkdir(parents=True, exist_ok=True)
            shutil.copy(t, out_dir / t.name)
        for v in val_imgs:
            out_dir = Path(val_dir) / person_dir.name
            out_dir.mkdir(parents=True, exist_ok=True)
            shutil.copy(v, out_dir / v.name)

split_train_val(processed_dir, train_dir, val_dir, val_split)

print("Clean and structured dataset ready for training.")
print(f"Train images in {train_dir}")
print(f"Validation images in {val_dir}")
# Out:
# Detected boxes for /kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/Aaron_Eckhart/Aaron_Eckhart_0001.jpg: [[82.02783966064453 68.76927185058594 165.00241088867188
#   178.15579223632812]]
# Processing images:   0%|          | 0/13233 [00:00<?, ?it/s]
# Saved face to /kaggle/working/processed_faces/Tyler_Hamilton/Tyler_Hamilton_0002.jpg
# Saved face to /kaggle/working/processed_faces/Tyler_Hamilton/Tyler_Hamilton_0001.jpg
# Saved face to /kaggle/working/processed_faces/Bernard_Siegel/Bernard_Siegel_0001.jpg
# Saved face to /kaggle/working/processed_faces/Blythe_Danner/Blythe_Danner_0002.jpg
# Saved face to /kaggle/working/processed_faces/Blythe_Danner/Blythe_Danner_0001.jpg
# Saved face to /kaggle/working/processed_faces/Gene_Robinson/Gene_Robinson_0003.jpg
# Saved face to /kaggle/working/processed_faces/Gene_Robinson/Gene_Robinson_0004.jpg
# Saved face to /kaggle/working/processed_faces/Gene_Robinson/Gene_Robinson_0001.jpg
# Saved face to /kaggle/working/processed_faces/Gene_Robinson/Gene_Robinson_0005.jpg
# Saved face to /kaggle/working/processed_faces/Gene_Robinson/Gene_Robinson_0002.jpg
# Saved face to /kaggle/working/processed_faces/Nicole_Parker/Nicole_Parker_0001.jpg
# Saved face to /kaggle/working/processed_faces/Coco_dEste/Coco_dEste_0001.jpg
# Saved face to /kaggle/working/processed_faces/Bernard_Ebbers/Bernard_Ebbers_0001.jpg
# Saved face to /kaggle/working/processed_faces/Ralph_Sampson/Ralph_Sampson_0001.jpg
# Saved face to /kaggle/working/processed_faces/Adam_Herbert/Adam_Herbert_0001.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0043.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0046.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0212.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0128.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0039.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0189.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0164.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0232.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0044.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0140.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0147.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0182.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0029.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0094.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0108.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0171.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0152.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0115.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0090.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0042.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0063.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0096.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0056.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0178.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0165.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0204.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0222.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0220.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0203.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0144.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0106.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0051.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0235.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0201.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0176.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0049.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0186.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0181.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0087.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0193.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0175.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0095.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0057.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0103.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0209.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0227.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0119.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0133.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0105.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0194.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0053.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0010.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0033.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0073.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0184.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0170.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0024.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0022.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0067.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0116.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0055.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0179.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0069.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0083.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0072.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0188.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0003.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0136.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0080.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0174.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0130.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0065.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0035.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0215.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0034.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0074.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0007.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0139.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0111.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0146.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0230.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0124.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0038.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0078.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0066.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0048.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0089.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0070.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0037.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0060.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0233.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0137.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0202.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0211.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0002.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0011.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0134.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0131.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0012.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0221.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0061.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0077.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0149.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0013.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0031.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0008.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0084.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0224.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0040.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0198.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0109.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0076.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0132.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0045.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0177.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0101.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0100.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0135.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0036.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0025.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0026.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0138.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0229.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0210.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0129.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0113.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0162.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0006.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0145.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0153.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0206.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0075.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0234.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0190.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0225.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0068.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0014.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0021.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0191.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0219.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0154.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0183.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0001.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0150.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0088.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0071.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0064.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0126.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0228.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0110.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0112.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0155.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0192.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0079.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0195.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0082.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0091.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0214.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0117.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0122.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0226.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0200.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0148.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0098.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0196.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0156.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0173.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0120.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0009.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0218.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0208.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0085.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0158.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0123.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0058.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0059.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0169.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0041.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0172.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0019.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0102.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0027.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0142.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0187.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0004.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0052.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0114.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0223.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0018.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0199.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0118.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0032.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0020.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0151.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0005.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0180.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0081.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0107.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0097.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0213.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0092.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0163.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0047.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0030.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0016.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0099.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0015.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0086.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0185.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0125.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0143.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0093.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0216.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0207.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0236.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0161.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0062.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0141.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0197.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0028.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0160.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0231.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0054.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0166.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0168.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0167.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0017.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0205.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0159.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0217.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0050.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0023.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0121.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0157.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0127.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Powell/Colin_Powell_0104.jpg
# Saved face to /kaggle/working/processed_faces/Eliott_Spitzer/Eliott_Spitzer_0001.jpg
# Saved face to /kaggle/working/processed_faces/Aicha_El_Ouafi/Aicha_El_Ouafi_0001.jpg
# Saved face to /kaggle/working/processed_faces/Aicha_El_Ouafi/Aicha_El_Ouafi_0002.jpg
# Saved face to /kaggle/working/processed_faces/Aicha_El_Ouafi/Aicha_El_Ouafi_0003.jpg
# Saved face to /kaggle/working/processed_faces/Luke_Walton/Luke_Walton_0001.jpg
# Saved face to /kaggle/working/processed_faces/Luke_Walton/Luke_Walton_0002.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Jasny/Michael_Jasny_0001.jpg
# Saved face to /kaggle/working/processed_faces/Xanana_Gusmao/Xanana_Gusmao_0003.jpg
# Saved face to /kaggle/working/processed_faces/Xanana_Gusmao/Xanana_Gusmao_0002.jpg
# Saved face to /kaggle/working/processed_faces/Xanana_Gusmao/Xanana_Gusmao_0004.jpg
# Saved face to /kaggle/working/processed_faces/Xanana_Gusmao/Xanana_Gusmao_0001.jpg
# Saved face to /kaggle/working/processed_faces/Xanana_Gusmao/Xanana_Gusmao_0005.jpg
# Saved face to /kaggle/working/processed_faces/Robert_Durst/Robert_Durst_0001.jpg
# Saved face to /kaggle/working/processed_faces/Sandy_Smith/Sandy_Smith_0001.jpg
# Saved face to /kaggle/working/processed_faces/Mohammed_Abulhasan/Mohammed_Abulhasan_0001.jpg
# Saved face to /kaggle/working/processed_faces/Kai-Uwe_Ricke/Kai-Uwe_Ricke_0001.jpg
# Saved face to /kaggle/working/processed_faces/Svend_Robinson/Svend_Robinson_0001.jpg
# Saved face to /kaggle/working/processed_faces/Emyr_Jones_Parry/Emyr_Jones_Parry_0001.jpg
# Saved face to /kaggle/working/processed_faces/Lawrence_MacAulay/Lawrence_MacAulay_0001.jpg
# Saved face to /kaggle/working/processed_faces/Lawrence_MacAulay/Lawrence_MacAulay_0002.jpg
# Saved face to /kaggle/working/processed_faces/Ahmed_Ghazi/Ahmed_Ghazi_0001.jpg
# Saved face to /kaggle/working/processed_faces/Mitchell_Garabedian/Mitchell_Garabedian_0001.jpg
# Saved face to /kaggle/working/processed_faces/Sonya_Walger/Sonya_Walger_0001.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0028.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0019.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0003.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0009.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0011.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0016.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0020.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0008.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0030.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0032.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0014.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0013.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0005.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0002.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0015.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0004.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0010.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0025.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0026.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0001.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0023.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0007.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0024.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0022.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0027.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0029.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0012.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0031.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0018.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0017.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0006.jpg
# Saved face to /kaggle/working/processed_faces/Roh_Moo-hyun/Roh_Moo-hyun_0021.jpg
# Saved face to /kaggle/working/processed_faces/Urmila_Matondkar/Urmila_Matondkar_0001.jpg
# Saved face to /kaggle/working/processed_faces/Hans_Eichel/Hans_Eichel_0003.jpg
# Saved face to /kaggle/working/processed_faces/Hans_Eichel/Hans_Eichel_0001.jpg
# Saved face to /kaggle/working/processed_faces/Hans_Eichel/Hans_Eichel_0002.jpg
# Saved face to /kaggle/working/processed_faces/Roberto_Canessa/Roberto_Canessa_0001.jpg
# Saved face to /kaggle/working/processed_faces/Win_Aung/Win_Aung_0002.jpg
# Saved face to /kaggle/working/processed_faces/Win_Aung/Win_Aung_0003.jpg
# Saved face to /kaggle/working/processed_faces/Win_Aung/Win_Aung_0001.jpg
# Saved face to /kaggle/working/processed_faces/Win_Aung/Win_Aung_0004.jpg
# Saved face to /kaggle/working/processed_faces/Roberto_Arguelles/Roberto_Arguelles_0001.jpg
# Saved face to /kaggle/working/processed_faces/Meryl_Streep/Meryl_Streep_0009.jpg
# Saved face to /kaggle/working/processed_faces/Meryl_Streep/Meryl_Streep_0015.jpg
# Saved face to /kaggle/working/processed_faces/Meryl_Streep/Meryl_Streep_0011.jpg
# Saved face to /kaggle/working/processed_faces/Meryl_Streep/Meryl_Streep_0004.jpg
# Saved face to /kaggle/working/processed_faces/Meryl_Streep/Meryl_Streep_0008.jpg
# Saved face to /kaggle/working/processed_faces/Meryl_Streep/Meryl_Streep_0012.jpg
# Saved face to /kaggle/working/processed_faces/Meryl_Streep/Meryl_Streep_0001.jpg
# Saved face to /kaggle/working/processed_faces/Meryl_Streep/Meryl_Streep_0005.jpg
# Saved face to /kaggle/working/processed_faces/Meryl_Streep/Meryl_Streep_0013.jpg
# Saved face to /kaggle/working/processed_faces/Meryl_Streep/Meryl_Streep_0010.jpg
# Saved face to /kaggle/working/processed_faces/Meryl_Streep/Meryl_Streep_0014.jpg
# Saved face to /kaggle/working/processed_faces/Meryl_Streep/Meryl_Streep_0007.jpg
# Saved face to /kaggle/working/processed_faces/Meryl_Streep/Meryl_Streep_0006.jpg
# Saved face to /kaggle/working/processed_faces/Meryl_Streep/Meryl_Streep_0003.jpg
# Saved face to /kaggle/working/processed_faces/Meryl_Streep/Meryl_Streep_0002.jpg
# Saved face to /kaggle/working/processed_faces/Mohammed_Abu_Sharia/Mohammed_Abu_Sharia_0001.jpg
# Saved face to /kaggle/working/processed_faces/Rita_Wilson/Rita_Wilson_0002.jpg
# Saved face to /kaggle/working/processed_faces/Rita_Wilson/Rita_Wilson_0003.jpg
# Saved face to /kaggle/working/processed_faces/Rita_Wilson/Rita_Wilson_0001.jpg
# Saved face to /kaggle/working/processed_faces/Rita_Wilson/Rita_Wilson_0004.jpg
# Saved face to /kaggle/working/processed_faces/Lonnie_Donegan/Lonnie_Donegan_0001.jpg
# Saved face to /kaggle/working/processed_faces/Michelle_Collins/Michelle_Collins_0002.jpg
# Saved face to /kaggle/working/processed_faces/Michelle_Collins/Michelle_Collins_0001.jpg
# Saved face to /kaggle/working/processed_faces/Joao_Rocha/Joao_Rocha_0001.jpg
# Saved face to /kaggle/working/processed_faces/Anthony_Lee_Johnson/Anthony_Lee_Johnson_0001.jpg
# Saved face to /kaggle/working/processed_faces/Fran_Drescher/Fran_Drescher_0002.jpg
# Saved face to /kaggle/working/processed_faces/Fran_Drescher/Fran_Drescher_0001.jpg
# Saved face to /kaggle/working/processed_faces/Robin_Williams/Robin_Williams_0001.jpg
# Saved face to /kaggle/working/processed_faces/Chris_Claiborne/Chris_Claiborne_0001.jpg
# Saved face to /kaggle/working/processed_faces/Kathy_Bates/Kathy_Bates_0001.jpg
# Saved face to /kaggle/working/processed_faces/Yasushi_Chimura/Yasushi_Chimura_0001.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0018.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0020.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0054.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0047.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0013.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0048.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0009.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0007.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0005.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0034.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0052.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0035.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0015.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0017.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0044.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0032.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0033.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0006.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0045.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0003.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0050.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0039.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0055.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0026.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0011.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0023.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0019.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0028.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0001.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0002.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0016.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0036.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0031.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0053.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0008.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0038.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0004.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0027.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0025.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0014.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0021.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0012.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0024.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0022.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0041.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0029.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0043.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0042.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0040.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0030.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0049.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0051.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0010.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0037.jpg
# Saved face to /kaggle/working/processed_faces/Jean_Chretien/Jean_Chretien_0046.jpg
# Saved face to /kaggle/working/processed_faces/Wolfgang_Becker/Wolfgang_Becker_0001.jpg
# Saved face to /kaggle/working/processed_faces/Minnie_Driver/Minnie_Driver_0001.jpg
# Saved face to /kaggle/working/processed_faces/Minnie_Driver/Minnie_Driver_0002.jpg
# Saved face to /kaggle/working/processed_faces/Benjamin_Bratt/Benjamin_Bratt_0001.jpg
# Saved face to /kaggle/working/processed_faces/Herb_Dhaliwal/Herb_Dhaliwal_0001.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Kostelnik/Michael_Kostelnik_0001.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Kostelnik/Michael_Kostelnik_0002.jpg
# Saved face to /kaggle/working/processed_faces/Stephen_Push/Stephen_Push_0001.jpg
# Saved face to /kaggle/working/processed_faces/Matt_Siebrandt/Matt_Siebrandt_0001.jpg
# Saved face to /kaggle/working/processed_faces/James_Carville/James_Carville_0001.jpg
# Saved face to /kaggle/working/processed_faces/Stephane_Delajoux/Stephane_Delajoux_0001.jpg
# Saved face to /kaggle/working/processed_faces/Madge_Overhouse/Madge_Overhouse_0001.jpg
# Saved face to /kaggle/working/processed_faces/Melissa_Gilbert/Melissa_Gilbert_0001.jpg
# Saved face to /kaggle/working/processed_faces/Raja_Ibrahim/Raja_Ibrahim_0001.jpg
# Saved face to /kaggle/working/processed_faces/Barry_Alvarez/Barry_Alvarez_0002.jpg
# Saved face to /kaggle/working/processed_faces/Barry_Alvarez/Barry_Alvarez_0001.jpg
# Saved face to /kaggle/working/processed_faces/Alex_Cabrera/Alex_Cabrera_0001.jpg
# Saved face to /kaggle/working/processed_faces/Owen_Wilson/Owen_Wilson_0001.jpg
# Saved face to /kaggle/working/processed_faces/Owen_Wilson/Owen_Wilson_0002.jpg
# Saved face to /kaggle/working/processed_faces/Daniela_Hantuchova/Daniela_Hantuchova_0001.jpg
# Saved face to /kaggle/working/processed_faces/Daniela_Hantuchova/Daniela_Hantuchova_0002.jpg
# Saved face to /kaggle/working/processed_faces/Damarius_Bilbo/Damarius_Bilbo_0001.jpg
# Saved face to /kaggle/working/processed_faces/Costas_Simitis/Costas_Simitis_0005.jpg
# Saved face to /kaggle/working/processed_faces/Costas_Simitis/Costas_Simitis_0006.jpg
# Saved face to /kaggle/working/processed_faces/Costas_Simitis/Costas_Simitis_0003.jpg
# Saved face to /kaggle/working/processed_faces/Costas_Simitis/Costas_Simitis_0001.jpg
# Saved face to /kaggle/working/processed_faces/Costas_Simitis/Costas_Simitis_0002.jpg
# Saved face to /kaggle/working/processed_faces/Costas_Simitis/Costas_Simitis_0004.jpg
# Saved face to /kaggle/working/processed_faces/Bernardo_Segura/Bernardo_Segura_0002.jpg
# Saved face to /kaggle/working/processed_faces/Bernardo_Segura/Bernardo_Segura_0001.jpg
# Saved face to /kaggle/working/processed_faces/Bill_Kollar/Bill_Kollar_0001.jpg
# Saved face to /kaggle/working/processed_faces/David_Przybyszewski/David_Przybyszewski_0001.jpg
# Saved face to /kaggle/working/processed_faces/Ian_Campbell/Ian_Campbell_0001.jpg
# Saved face to /kaggle/working/processed_faces/Carin_Koch/Carin_Koch_0001.jpg
# Saved face to /kaggle/working/processed_faces/Steve_Alford/Steve_Alford_0001.jpg
# Saved face to /kaggle/working/processed_faces/Mario_Jardel/Mario_Jardel_0001.jpg
# Saved face to /kaggle/working/processed_faces/Hilary_McKay/Hilary_McKay_0001.jpg
# Saved face to /kaggle/working/processed_faces/Elsa_Zylberstein/Elsa_Zylberstein_0002.jpg
# Saved face to /kaggle/working/processed_faces/Elsa_Zylberstein/Elsa_Zylberstein_0006.jpg
# Saved face to /kaggle/working/processed_faces/Elsa_Zylberstein/Elsa_Zylberstein_0005.jpg
# Saved face to /kaggle/working/processed_faces/Elsa_Zylberstein/Elsa_Zylberstein_0001.jpg
# Saved face to /kaggle/working/processed_faces/Elsa_Zylberstein/Elsa_Zylberstein_0004.jpg
# Saved face to /kaggle/working/processed_faces/Elsa_Zylberstein/Elsa_Zylberstein_0003.jpg
# Saved face to /kaggle/working/processed_faces/Katrin_Cartlidge/Katrin_Cartlidge_0001.jpg
# Saved face to /kaggle/working/processed_faces/Claudette_Robinson/Claudette_Robinson_0001.jpg
# Saved face to /kaggle/working/processed_faces/Uday_Hussein/Uday_Hussein_0001.jpg
# Saved face to /kaggle/working/processed_faces/Fred_Swan/Fred_Swan_0001.jpg
# Saved face to /kaggle/working/processed_faces/Yusuf_Misbac/Yusuf_Misbac_0001.jpg
# Saved face to /kaggle/working/processed_faces/Yoo_Jay-Kun/Yoo_Jay-Kun_0001.jpg
# Saved face to /kaggle/working/processed_faces/Natalia_Verbeke/Natalia_Verbeke_0001.jpg
# Saved face to /kaggle/working/processed_faces/Carson_Daly/Carson_Daly_0002.jpg
# Saved face to /kaggle/working/processed_faces/Carson_Daly/Carson_Daly_0001.jpg
# Saved face to /kaggle/working/processed_faces/Thomas_Van_Essen/Thomas_Van_Essen_0001.jpg
# Saved face to /kaggle/working/processed_faces/Florecita_Cobian/Florecita_Cobian_0001.jpg
# Saved face to /kaggle/working/processed_faces/George_Foreman/George_Foreman_0001.jpg
# Saved face to /kaggle/working/processed_faces/George_Foreman/George_Foreman_0002.jpg
# Saved face to /kaggle/working/processed_faces/Nelson_Mandela/Nelson_Mandela_0003.jpg
# Saved face to /kaggle/working/processed_faces/Nelson_Mandela/Nelson_Mandela_0002.jpg
# Saved face to /kaggle/working/processed_faces/Nelson_Mandela/Nelson_Mandela_0001.jpg
# Saved face to /kaggle/working/processed_faces/Nelson_Mandela/Nelson_Mandela_0004.jpg
# Saved face to /kaggle/working/processed_faces/Alanis_Morissette/Alanis_Morissette_0001.jpg
# Saved face to /kaggle/working/processed_faces/Jackie_Dennis/Jackie_Dennis_0001.jpg
# Saved face to /kaggle/working/processed_faces/Tommy_Shane_Steiner/Tommy_Shane_Steiner_0001.jpg
# Saved face to /kaggle/working/processed_faces/Leonardo_Fernandez/Leonardo_Fernandez_0001.jpg
# Saved face to /kaggle/working/processed_faces/James_W_Kennedy/James_W_Kennedy_0001.jpg
# Saved face to /kaggle/working/processed_faces/Mark_Hanson/Mark_Hanson_0001.jpg
# Saved face to /kaggle/working/processed_faces/Rina_Lazo/Rina_Lazo_0001.jpg
# Saved face to /kaggle/working/processed_faces/Akbar_Hashemi_Rafsanjani/Akbar_Hashemi_Rafsanjani_0003.jpg
# Saved face to /kaggle/working/processed_faces/Akbar_Hashemi_Rafsanjani/Akbar_Hashemi_Rafsanjani_0002.jpg
# Saved face to /kaggle/working/processed_faces/Akbar_Hashemi_Rafsanjani/Akbar_Hashemi_Rafsanjani_0001.jpg
# Saved face to /kaggle/working/processed_faces/Mike_Slive/Mike_Slive_0001.jpg
# Saved face to /kaggle/working/processed_faces/Stanley_Nelson/Stanley_Nelson_0001.jpg
# Saved face to /kaggle/working/processed_faces/Jong_Thae_Hwa/Jong_Thae_Hwa_0002.jpg
# Saved face to /kaggle/working/processed_faces/Jong_Thae_Hwa/Jong_Thae_Hwa_0001.jpg
# Saved face to /kaggle/working/processed_faces/Faye_Dunaway/Faye_Dunaway_0001.jpg
# Saved face to /kaggle/working/processed_faces/Faye_Dunaway/Faye_Dunaway_0003.jpg
# Saved face to /kaggle/working/processed_faces/Faye_Dunaway/Faye_Dunaway_0002.jpg
# Saved face to /kaggle/working/processed_faces/Roy_Halladay/Roy_Halladay_0001.jpg
# Saved face to /kaggle/working/processed_faces/Martha_Lucia_Ramirez/Martha_Lucia_Ramirez_0002.jpg
# Saved face to /kaggle/working/processed_faces/Martha_Lucia_Ramirez/Martha_Lucia_Ramirez_0003.jpg
# Saved face to /kaggle/working/processed_faces/Martha_Lucia_Ramirez/Martha_Lucia_Ramirez_0004.jpg
# Saved face to /kaggle/working/processed_faces/Martha_Lucia_Ramirez/Martha_Lucia_Ramirez_0001.jpg
# Saved face to /kaggle/working/processed_faces/Aidan_Quinn/Aidan_Quinn_0001.jpg
# Saved face to /kaggle/working/processed_faces/John_Norquist/John_Norquist_0001.jpg
# Saved face to /kaggle/working/processed_faces/Charla_Moye/Charla_Moye_0001.jpg
# Saved face to /kaggle/working/processed_faces/Liv_Tyler/Liv_Tyler_0001.jpg
# Saved face to /kaggle/working/processed_faces/Conchita_Martinez/Conchita_Martinez_0001.jpg
# Saved face to /kaggle/working/processed_faces/Conchita_Martinez/Conchita_Martinez_0003.jpg
# Saved face to /kaggle/working/processed_faces/Conchita_Martinez/Conchita_Martinez_0002.jpg
# Saved face to /kaggle/working/processed_faces/Marissa_Jaret_Winokur/Marissa_Jaret_Winokur_0002.jpg
# Saved face to /kaggle/working/processed_faces/Marissa_Jaret_Winokur/Marissa_Jaret_Winokur_0001.jpg
# Saved face to /kaggle/working/processed_faces/Yingfan_Wang/Yingfan_Wang_0001.jpg
# Saved face to /kaggle/working/processed_faces/Emmit_Smith/Emmit_Smith_0002.jpg
# Saved face to /kaggle/working/processed_faces/Emmit_Smith/Emmit_Smith_0001.jpg
# Saved face to /kaggle/working/processed_faces/Naomi_Hayashi/Naomi_Hayashi_0001.jpg
# Saved face to /kaggle/working/processed_faces/Billy_Edelin/Billy_Edelin_0001.jpg
# Saved face to /kaggle/working/processed_faces/Matt_Walters/Matt_Walters_0001.jpg
# Saved face to /kaggle/working/processed_faces/Omar_Sharif/Omar_Sharif_0002.jpg
# Saved face to /kaggle/working/processed_faces/Omar_Sharif/Omar_Sharif_0001.jpg
# Saved face to /kaggle/working/processed_faces/Omar_Sharif/Omar_Sharif_0004.jpg
# Saved face to /kaggle/working/processed_faces/Omar_Sharif/Omar_Sharif_0003.jpg
# Saved face to /kaggle/working/processed_faces/Thabo_Mbeki/Thabo_Mbeki_0004.jpg
# Saved face to /kaggle/working/processed_faces/Thabo_Mbeki/Thabo_Mbeki_0005.jpg
# Saved face to /kaggle/working/processed_faces/Thabo_Mbeki/Thabo_Mbeki_0001.jpg
# Saved face to /kaggle/working/processed_faces/Thabo_Mbeki/Thabo_Mbeki_0002.jpg
# Saved face to /kaggle/working/processed_faces/Thabo_Mbeki/Thabo_Mbeki_0003.jpg
# Saved face to /kaggle/working/processed_faces/Manfred_Stolpe/Manfred_Stolpe_0001.jpg
# Saved face to /kaggle/working/processed_faces/Manfred_Stolpe/Manfred_Stolpe_0002.jpg
# Saved face to /kaggle/working/processed_faces/George_Murphy/George_Murphy_0001.jpg
# Saved face to /kaggle/working/processed_faces/Koichi_Haraguchi/Koichi_Haraguchi_0001.jpg
# Saved face to /kaggle/working/processed_faces/James_Hoffa/James_Hoffa_0001.jpg
# Saved face to /kaggle/working/processed_faces/Alejandro_Atchugarry/Alejandro_Atchugarry_0001.jpg
# Saved face to /kaggle/working/processed_faces/Alejandro_Atchugarry/Alejandro_Atchugarry_0002.jpg
# Saved face to /kaggle/working/processed_faces/Robby_Ginepri/Robby_Ginepri_0001.jpg
# Saved face to /kaggle/working/processed_faces/Robby_Ginepri/Robby_Ginepri_0002.jpg
# Saved face to /kaggle/working/processed_faces/Stella_McCartney/Stella_McCartney_0001.jpg
# Saved face to /kaggle/working/processed_faces/Robert_Mueller/Robert_Mueller_0004.jpg
# Saved face to /kaggle/working/processed_faces/Robert_Mueller/Robert_Mueller_0002.jpg
# Saved face to /kaggle/working/processed_faces/Robert_Mueller/Robert_Mueller_0003.jpg
# Saved face to /kaggle/working/processed_faces/Robert_Mueller/Robert_Mueller_0005.jpg
# Saved face to /kaggle/working/processed_faces/Robert_Mueller/Robert_Mueller_0001.jpg
# Saved face to /kaggle/working/processed_faces/Don_Meredith/Don_Meredith_0001.jpg
# Saved face to /kaggle/working/processed_faces/Izzat_Ibrahim/Izzat_Ibrahim_0001.jpg
# Saved face to /kaggle/working/processed_faces/Kirk_Douglas/Kirk_Douglas_0001.jpg
# Saved face to /kaggle/working/processed_faces/Steven_Feldman/Steven_Feldman_0001.jpg
# Saved face to /kaggle/working/processed_faces/Deb_Santos/Deb_Santos_0001.jpg
# Saved face to /kaggle/working/processed_faces/Tomomi_Morita/Tomomi_Morita_0001.jpg
# Saved face to /kaggle/working/processed_faces/Job_Cohen/Job_Cohen_0002.jpg
# Saved face to /kaggle/working/processed_faces/Job_Cohen/Job_Cohen_0001.jpg
# Saved face to /kaggle/working/processed_faces/Kurt_Suzuki/Kurt_Suzuki_0001.jpg
# Saved face to /kaggle/working/processed_faces/Bertrand_Bonello/Bertrand_Bonello_0002.jpg
# Saved face to /kaggle/working/processed_faces/Bertrand_Bonello/Bertrand_Bonello_0001.jpg
# Saved face to /kaggle/working/processed_faces/Kimberly_Stewart/Kimberly_Stewart_0001.jpg
# Saved face to /kaggle/working/processed_faces/Joaquim_Levy/Joaquim_Levy_0001.jpg
# Saved face to /kaggle/working/processed_faces/Nathalie_Dechy/Nathalie_Dechy_0001.jpg
# Saved face to /kaggle/working/processed_faces/Jim_Parque/Jim_Parque_0001.jpg
# Saved face to /kaggle/working/processed_faces/Geraldine_Chaplin/Geraldine_Chaplin_0001.jpg
# Saved face to /kaggle/working/processed_faces/Geraldine_Chaplin/Geraldine_Chaplin_0003.jpg
# Saved face to /kaggle/working/processed_faces/Geraldine_Chaplin/Geraldine_Chaplin_0002.jpg
# Saved face to /kaggle/working/processed_faces/Geraldine_Chaplin/Geraldine_Chaplin_0004.jpg
# Saved face to /kaggle/working/processed_faces/David_Duke/David_Duke_0001.jpg
# Saved face to /kaggle/working/processed_faces/James_Wattana/James_Wattana_0001.jpg
# Saved face to /kaggle/working/processed_faces/Martin_Hoellwarth/Martin_Hoellwarth_0002.jpg
# Saved face to /kaggle/working/processed_faces/Martin_Hoellwarth/Martin_Hoellwarth_0001.jpg
# Saved face to /kaggle/working/processed_faces/Kristen_Breitweiser/Kristen_Breitweiser_0001.jpg
# Saved face to /kaggle/working/processed_faces/Kristen_Breitweiser/Kristen_Breitweiser_0002.jpg
# Saved face to /kaggle/working/processed_faces/Kristen_Breitweiser/Kristen_Breitweiser_0003.jpg
# Saved face to /kaggle/working/processed_faces/Bertrand_Delanoe/Bertrand_Delanoe_0001.jpg
# Saved face to /kaggle/working/processed_faces/Nikki_Reed/Nikki_Reed_0002.jpg
# Saved face to /kaggle/working/processed_faces/Nikki_Reed/Nikki_Reed_0001.jpg
# Saved face to /kaggle/working/processed_faces/Howard_Schultz/Howard_Schultz_0002.jpg
# Saved face to /kaggle/working/processed_faces/Howard_Schultz/Howard_Schultz_0001.jpg
# Saved face to /kaggle/working/processed_faces/Lope_Mendoza/Lope_Mendoza_0001.jpg
# Saved face to /kaggle/working/processed_faces/David_Alpay/David_Alpay_0001.jpg
# Saved face to /kaggle/working/processed_faces/Alistair_MacDonald/Alistair_MacDonald_0001.jpg
# Saved face to /kaggle/working/processed_faces/Dinah_Turner/Dinah_Turner_0001.jpg
# Saved face to /kaggle/working/processed_faces/Lesley_McCulloch/Lesley_McCulloch_0001.jpg
# Saved face to /kaggle/working/processed_faces/Lesley_McCulloch/Lesley_McCulloch_0002.jpg
# Saved face to /kaggle/working/processed_faces/Lesley_McCulloch/Lesley_McCulloch_0003.jpg
# Saved face to /kaggle/working/processed_faces/Andrew_Shutley/Andrew_Shutley_0001.jpg
# Saved face to /kaggle/working/processed_faces/Alexandra_Pelosi/Alexandra_Pelosi_0001.jpg
# Saved face to /kaggle/working/processed_faces/Benjamin_Franklin/Benjamin_Franklin_0001.jpg
# Saved face to /kaggle/working/processed_faces/Jason_Kapono/Jason_Kapono_0001.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Jackson/Colin_Jackson_0001.jpg
# Saved face to /kaggle/working/processed_faces/Colin_Jackson/Colin_Jackson_0002.jpg
# Saved face to /kaggle/working/processed_faces/Harold_Scott/Harold_Scott_0001.jpg
# Saved face to /kaggle/working/processed_faces/Carroll_Weimer/Carroll_Weimer_0001.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Taylor/Michael_Taylor_0001.jpg
# Saved face to /kaggle/working/processed_faces/Darin_Erstad/Darin_Erstad_0001.jpg
# Saved face to /kaggle/working/processed_faces/Juergen_Trittin/Juergen_Trittin_0001.jpg
# Saved face to /kaggle/working/processed_faces/Milo_Djukanovic/Milo_Djukanovic_0003.jpg
# Saved face to /kaggle/working/processed_faces/Milo_Djukanovic/Milo_Djukanovic_0002.jpg
# Saved face to /kaggle/working/processed_faces/Milo_Djukanovic/Milo_Djukanovic_0001.jpg
# Saved face to /kaggle/working/processed_faces/David_Trimble/David_Trimble_0005.jpg
# ...
# Saved face to /kaggle/working/processed_faces/Dave_McGinnis/Dave_McGinnis_0001.jpg
# Saved face to /kaggle/working/processed_faces/Norodom_Chakrapong/Norodom_Chakrapong_0001.jpg
# Saved face to /kaggle/working/processed_faces/Sidney_Kimmel/Sidney_Kimmel_0001.jpg
# Saved face to /kaggle/working/processed_faces/Leon_Lai/Leon_Lai_0001.jpg
# Saved face to /kaggle/working/processed_faces/Christopher_Patten/Christopher_Patten_0002.jpg
# Saved face to /kaggle/working/processed_faces/Christopher_Patten/Christopher_Patten_0001.jpg
# Saved face to /kaggle/working/processed_faces/Tamika_Catchings/Tamika_Catchings_0001.jpg
# Saved face to /kaggle/working/processed_faces/Chen_Liang_Yu/Chen_Liang_Yu_0002.jpg
# Saved face to /kaggle/working/processed_faces/Chen_Liang_Yu/Chen_Liang_Yu_0001.jpg
# Saved face to /kaggle/working/processed_faces/Hugh_Campbell/Hugh_Campbell_0001.jpg
# Saved face to /kaggle/working/processed_faces/Bernard_Kerik/Bernard_Kerik_0001.jpg
# Saved face to /kaggle/working/processed_faces/Zhang_Ziyi/Zhang_Ziyi_0003.jpg
# Saved face to /kaggle/working/processed_faces/Zhang_Ziyi/Zhang_Ziyi_0001.jpg
# Saved face to /kaggle/working/processed_faces/Zhang_Ziyi/Zhang_Ziyi_0002.jpg
# Saved face to /kaggle/working/processed_faces/Zhang_Ziyi/Zhang_Ziyi_0004.jpg
# Saved face to /kaggle/working/processed_faces/Paul_Celluci/Paul_Celluci_0001.jpg
# Saved face to /kaggle/working/processed_faces/Lisa_Stone/Lisa_Stone_0001.jpg
# Saved face to /kaggle/working/processed_faces/Eduardo_Duhalde/Eduardo_Duhalde_0012.jpg
# Saved face to /kaggle/working/processed_faces/Eduardo_Duhalde/Eduardo_Duhalde_0009.jpg
# Saved face to /kaggle/working/processed_faces/Eduardo_Duhalde/Eduardo_Duhalde_0010.jpg
# Saved face to /kaggle/working/processed_faces/Eduardo_Duhalde/Eduardo_Duhalde_0004.jpg
# Saved face to /kaggle/working/processed_faces/Eduardo_Duhalde/Eduardo_Duhalde_0014.jpg
# Saved face to /kaggle/working/processed_faces/Eduardo_Duhalde/Eduardo_Duhalde_0003.jpg
# Saved face to /kaggle/working/processed_faces/Eduardo_Duhalde/Eduardo_Duhalde_0001.jpg
# Saved face to /kaggle/working/processed_faces/Eduardo_Duhalde/Eduardo_Duhalde_0008.jpg
# Saved face to /kaggle/working/processed_faces/Eduardo_Duhalde/Eduardo_Duhalde_0006.jpg
# Saved face to /kaggle/working/processed_faces/Eduardo_Duhalde/Eduardo_Duhalde_0011.jpg
# Saved face to /kaggle/working/processed_faces/Eduardo_Duhalde/Eduardo_Duhalde_0005.jpg
# Saved face to /kaggle/working/processed_faces/Eduardo_Duhalde/Eduardo_Duhalde_0013.jpg
# Saved face to /kaggle/working/processed_faces/Eduardo_Duhalde/Eduardo_Duhalde_0007.jpg
# Saved face to /kaggle/working/processed_faces/Eduardo_Duhalde/Eduardo_Duhalde_0002.jpg
# Saved face to /kaggle/working/processed_faces/Jeff_Hornacek/Jeff_Hornacek_0001.jpg
# Saved face to /kaggle/working/processed_faces/Martin_Brodeur/Martin_Brodeur_0001.jpg
# Saved face to /kaggle/working/processed_faces/Martin_Brodeur/Martin_Brodeur_0002.jpg
# Saved face to /kaggle/working/processed_faces/Abba_Eban/Abba_Eban_0001.jpg
# Saved face to /kaggle/working/processed_faces/Diego_Colorado/Diego_Colorado_0001.jpg
# Saved face to /kaggle/working/processed_faces/David_Dewhurst/David_Dewhurst_0001.jpg
# Saved face to /kaggle/working/processed_faces/Abdullah_al-Attiyah/Abdullah_al-Attiyah_0002.jpg
# Saved face to /kaggle/working/processed_faces/Abdullah_al-Attiyah/Abdullah_al-Attiyah_0001.jpg
# Saved face to /kaggle/working/processed_faces/Abdullah_al-Attiyah/Abdullah_al-Attiyah_0003.jpg
# Saved face to /kaggle/working/processed_faces/Suzanne_Somers/Suzanne_Somers_0001.jpg
# Saved face to /kaggle/working/processed_faces/Ekke_Hard_Forberg/Ekke_Hard_Forberg_0001.jpg
# Saved face to /kaggle/working/processed_faces/Jorge_Castaneda/Jorge_Castaneda_0002.jpg
# Saved face to /kaggle/working/processed_faces/Jorge_Castaneda/Jorge_Castaneda_0001.jpg
# Saved face to /kaggle/working/processed_faces/Richard_Pennington/Richard_Pennington_0001.jpg
# Saved face to /kaggle/working/processed_faces/Lawrence_Foley/Lawrence_Foley_0001.jpg
# Saved face to /kaggle/working/processed_faces/Marco_Antonio_Barrera/Marco_Antonio_Barrera_0004.jpg
# Saved face to /kaggle/working/processed_faces/Marco_Antonio_Barrera/Marco_Antonio_Barrera_0005.jpg
# Saved face to /kaggle/working/processed_faces/Marco_Antonio_Barrera/Marco_Antonio_Barrera_0001.jpg
# Saved face to /kaggle/working/processed_faces/Marco_Antonio_Barrera/Marco_Antonio_Barrera_0002.jpg
# Saved face to /kaggle/working/processed_faces/Marco_Antonio_Barrera/Marco_Antonio_Barrera_0003.jpg
# Saved face to /kaggle/working/processed_faces/Marco_Antonio_Barrera/Marco_Antonio_Barrera_0006.jpg
# Saved face to /kaggle/working/processed_faces/Bud_Selig/Bud_Selig_0001.jpg
# Saved face to /kaggle/working/processed_faces/Bud_Selig/Bud_Selig_0002.jpg
# Saved face to /kaggle/working/processed_faces/Bud_Selig/Bud_Selig_0004.jpg
# Saved face to /kaggle/working/processed_faces/Bud_Selig/Bud_Selig_0003.jpg
# Saved face to /kaggle/working/processed_faces/Kamel_Morjane/Kamel_Morjane_0001.jpg
# Saved face to /kaggle/working/processed_faces/Nadine_Vinzens/Nadine_Vinzens_0002.jpg
# Saved face to /kaggle/working/processed_faces/Nadine_Vinzens/Nadine_Vinzens_0001.jpg
# Saved face to /kaggle/working/processed_faces/Maritza_Macias_Furano/Maritza_Macias_Furano_0001.jpg
# Saved face to /kaggle/working/processed_faces/Tatyana_Tomashova/Tatyana_Tomashova_0001.jpg
# Saved face to /kaggle/working/processed_faces/Dick_Posthumus/Dick_Posthumus_0001.jpg
# Saved face to /kaggle/working/processed_faces/Aline_Chretien/Aline_Chretien_0001.jpg
# Saved face to /kaggle/working/processed_faces/Tony_Clement/Tony_Clement_0001.jpg
# Saved face to /kaggle/working/processed_faces/Mary_Tyler_Moore/Mary_Tyler_Moore_0002.jpg
# Saved face to /kaggle/working/processed_faces/Mary_Tyler_Moore/Mary_Tyler_Moore_0001.jpg
# Saved face to /kaggle/working/processed_faces/Rodolfo_Abalos/Rodolfo_Abalos_0001.jpg
# Saved face to /kaggle/working/processed_faces/Carlton_Dotson/Carlton_Dotson_0001.jpg
# Saved face to /kaggle/working/processed_faces/Wayne_Brady/Wayne_Brady_0001.jpg
# Saved face to /kaggle/working/processed_faces/Andy_Roddick/Andy_Roddick_0003.jpg
# Saved face to /kaggle/working/processed_faces/Andy_Roddick/Andy_Roddick_0007.jpg
# Saved face to /kaggle/working/processed_faces/Andy_Roddick/Andy_Roddick_0012.jpg
# Saved face to /kaggle/working/processed_faces/Andy_Roddick/Andy_Roddick_0002.jpg
# Saved face to /kaggle/working/processed_faces/Andy_Roddick/Andy_Roddick_0009.jpg
# Saved face to /kaggle/working/processed_faces/Andy_Roddick/Andy_Roddick_0006.jpg
# Saved face to /kaggle/working/processed_faces/Andy_Roddick/Andy_Roddick_0010.jpg
# Saved face to /kaggle/working/processed_faces/Andy_Roddick/Andy_Roddick_0015.jpg
# Saved face to /kaggle/working/processed_faces/Andy_Roddick/Andy_Roddick_0004.jpg
# Saved face to /kaggle/working/processed_faces/Andy_Roddick/Andy_Roddick_0001.jpg
# Saved face to /kaggle/working/processed_faces/Andy_Roddick/Andy_Roddick_0011.jpg
# Saved face to /kaggle/working/processed_faces/Andy_Roddick/Andy_Roddick_0013.jpg
# Saved face to /kaggle/working/processed_faces/Andy_Roddick/Andy_Roddick_0005.jpg
# Saved face to /kaggle/working/processed_faces/Andy_Roddick/Andy_Roddick_0008.jpg
# Saved face to /kaggle/working/processed_faces/Andy_Roddick/Andy_Roddick_0014.jpg
# Saved face to /kaggle/working/processed_faces/James_Young/James_Young_0001.jpg
# Saved face to /kaggle/working/processed_faces/Mario_Cipollini/Mario_Cipollini_0002.jpg
# Saved face to /kaggle/working/processed_faces/Mario_Cipollini/Mario_Cipollini_0001.jpg
# Saved face to /kaggle/working/processed_faces/Carla_Tricoli/Carla_Tricoli_0001.jpg
# Saved face to /kaggle/working/processed_faces/Mark_Warner/Mark_Warner_0002.jpg
# Saved face to /kaggle/working/processed_faces/Mark_Warner/Mark_Warner_0001.jpg
# Saved face to /kaggle/working/processed_faces/Bruce_Paltrow/Bruce_Paltrow_0001.jpg
# Saved face to /kaggle/working/processed_faces/Galen_Rowell/Galen_Rowell_0001.jpg
# Saved face to /kaggle/working/processed_faces/Casy_Preslar/Casy_Preslar_0001.jpg
# Saved face to /kaggle/working/processed_faces/Zakia_Hakki/Zakia_Hakki_0001.jpg
# Saved face to /kaggle/working/processed_faces/Tom_Schnackenberg/Tom_Schnackenberg_0001.jpg
# Saved face to /kaggle/working/processed_faces/Brian_Cashman/Brian_Cashman_0001.jpg
# Saved face to /kaggle/working/processed_faces/Cristina_Saralegui/Cristina_Saralegui_0001.jpg
# Saved face to /kaggle/working/processed_faces/Cristina_Saralegui/Cristina_Saralegui_0002.jpg
# Saved face to /kaggle/working/processed_faces/Sally_Clark/Sally_Clark_0001.jpg
# Saved face to /kaggle/working/processed_faces/Rachel_Kempson/Rachel_Kempson_0001.jpg
# Saved face to /kaggle/working/processed_faces/Michelangelo_Antonioni/Michelangelo_Antonioni_0001.jpg
# Saved face to /kaggle/working/processed_faces/Patrick_Clawsen/Patrick_Clawsen_0001.jpg
# Saved face to /kaggle/working/processed_faces/Fabricio_Oberto/Fabricio_Oberto_0001.jpg
# Saved face to /kaggle/working/processed_faces/Lindsey_Graham/Lindsey_Graham_0002.jpg
# Saved face to /kaggle/working/processed_faces/Lindsey_Graham/Lindsey_Graham_0001.jpg
# Saved face to /kaggle/working/processed_faces/John_Darby/John_Darby_0001.jpg
# Saved face to /kaggle/working/processed_faces/Ray_Nagin/Ray_Nagin_0001.jpg
# Saved face to /kaggle/working/processed_faces/Ray_Nagin/Ray_Nagin_0002.jpg
# Saved face to /kaggle/working/processed_faces/Dave_McNealey/Dave_McNealey_0001.jpg
# Saved face to /kaggle/working/processed_faces/Dwayne_Wade/Dwayne_Wade_0001.jpg
# Saved face to /kaggle/working/processed_faces/Susie_Castillo/Susie_Castillo_0002.jpg
# Saved face to /kaggle/working/processed_faces/Susie_Castillo/Susie_Castillo_0001.jpg
# Saved face to /kaggle/working/processed_faces/Angie_Martinez/Angie_Martinez_0001.jpg
# Saved face to /kaggle/working/processed_faces/Timothy_Coughlin/Timothy_Coughlin_0001.jpg
# Saved face to /kaggle/working/processed_faces/Cecile_de_France/Cecile_de_France_0001.jpg
# Saved face to /kaggle/working/processed_faces/Gina_Gershon/Gina_Gershon_0001.jpg
# Saved face to /kaggle/working/processed_faces/Gregorio_Honasan/Gregorio_Honasan_0001.jpg
# Saved face to /kaggle/working/processed_faces/Ain_Seppik/Ain_Seppik_0001.jpg
# Saved face to /kaggle/working/processed_faces/Timothy_McVeigh/Timothy_McVeigh_0001.jpg
# Saved face to /kaggle/working/processed_faces/Gavin_Degraw/Gavin_Degraw_0001.jpg
# Saved face to /kaggle/working/processed_faces/James_Harris/James_Harris_0001.jpg
# Saved face to /kaggle/working/processed_faces/Theo_Angelopoulos/Theo_Angelopoulos_0001.jpg
# Saved face to /kaggle/working/processed_faces/Gary_Bauer/Gary_Bauer_0001.jpg
# Saved face to /kaggle/working/processed_faces/Roy_Rogers/Roy_Rogers_0001.jpg
# Saved face to /kaggle/working/processed_faces/Valdas_Adamkus/Valdas_Adamkus_0001.jpg
# Saved face to /kaggle/working/processed_faces/Valdas_Adamkus/Valdas_Adamkus_0002.jpg
# Saved face to /kaggle/working/processed_faces/Lars_Burgsmuller/Lars_Burgsmuller_0001.jpg
# Saved face to /kaggle/working/processed_faces/Roger_Grimes/Roger_Grimes_0001.jpg
# Saved face to /kaggle/working/processed_faces/Ashley_Postell/Ashley_Postell_0001.jpg
# Saved face to /kaggle/working/processed_faces/Anthony_Scott_Miller/Anthony_Scott_Miller_0001.jpg
# Saved face to /kaggle/working/processed_faces/Ajit_Agarkar/Ajit_Agarkar_0001.jpg
# Saved face to /kaggle/working/processed_faces/Sonja_Kesselschlager/Sonja_Kesselschlager_0001.jpg
# Saved face to /kaggle/working/processed_faces/Shoshana_Johnson/Shoshana_Johnson_0001.jpg
# Saved face to /kaggle/working/processed_faces/Martie_Maguire/Martie_Maguire_0001.jpg
# Saved face to /kaggle/working/processed_faces/Bruce_Springsteen/Bruce_Springsteen_0001.jpg
# Saved face to /kaggle/working/processed_faces/Bruce_Springsteen/Bruce_Springsteen_0002.jpg
# Saved face to /kaggle/working/processed_faces/Bruce_Springsteen/Bruce_Springsteen_0003.jpg
# Saved face to /kaggle/working/processed_faces/Bruce_Springsteen/Bruce_Springsteen_0004.jpg
# Saved face to /kaggle/working/processed_faces/Aby_Har-Even/Aby_Har-Even_0001.jpg
# Saved face to /kaggle/working/processed_faces/Jim_Hendry/Jim_Hendry_0001.jpg
# Saved face to /kaggle/working/processed_faces/Mohammad_Hasanein/Mohammad_Hasanein_0001.jpg
# Saved face to /kaggle/working/processed_faces/Kathryn_Grayson/Kathryn_Grayson_0001.jpg
# Saved face to /kaggle/working/processed_faces/Richard_Norton-Taylor/Richard_Norton-Taylor_0001.jpg
# Saved face to /kaggle/working/processed_faces/Richard_Norton-Taylor/Richard_Norton-Taylor_0002.jpg
# Saved face to /kaggle/working/processed_faces/Raaf_Schefter/Raaf_Schefter_0001.jpg
# Saved face to /kaggle/working/processed_faces/Eddie_Murray/Eddie_Murray_0001.jpg
# Saved face to /kaggle/working/processed_faces/Glenn_Tilton/Glenn_Tilton_0001.jpg
# Saved face to /kaggle/working/processed_faces/Carlos_Manuel_Pruneda/Carlos_Manuel_Pruneda_0001.jpg
# Saved face to /kaggle/working/processed_faces/Carlos_Manuel_Pruneda/Carlos_Manuel_Pruneda_0002.jpg
# Saved face to /kaggle/working/processed_faces/Carlos_Manuel_Pruneda/Carlos_Manuel_Pruneda_0003.jpg
# Saved face to /kaggle/working/processed_faces/Huang_Suey-Sheng/Huang_Suey-Sheng_0001.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Bloomberg/Michael_Bloomberg_0008.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Bloomberg/Michael_Bloomberg_0001.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Bloomberg/Michael_Bloomberg_0002.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Bloomberg/Michael_Bloomberg_0016.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Bloomberg/Michael_Bloomberg_0012.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Bloomberg/Michael_Bloomberg_0019.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Bloomberg/Michael_Bloomberg_0005.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Bloomberg/Michael_Bloomberg_0006.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Bloomberg/Michael_Bloomberg_0004.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Bloomberg/Michael_Bloomberg_0020.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Bloomberg/Michael_Bloomberg_0010.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Bloomberg/Michael_Bloomberg_0003.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Bloomberg/Michael_Bloomberg_0018.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Bloomberg/Michael_Bloomberg_0015.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Bloomberg/Michael_Bloomberg_0009.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Bloomberg/Michael_Bloomberg_0014.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Bloomberg/Michael_Bloomberg_0007.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Bloomberg/Michael_Bloomberg_0011.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Bloomberg/Michael_Bloomberg_0017.jpg
# Saved face to /kaggle/working/processed_faces/Michael_Bloomberg/Michael_Bloomberg_0013.jpg
# Saved face to /kaggle/working/processed_faces/Artieas_Shanks/Artieas_Shanks_0001.jpg
# Saved face to /kaggle/working/processed_faces/Peter_Ahearn/Peter_Ahearn_0001.jpg
# Saved face to /kaggle/working/processed_faces/Scott_Yates/Scott_Yates_0001.jpg
# Saved face to /kaggle/working/processed_faces/Valerie_Harper/Valerie_Harper_0001.jpg
# Saved face to /kaggle/working/processed_faces/Valerie_Harper/Valerie_Harper_0002.jpg
# Saved face to /kaggle/working/processed_faces/Mstislav_Rostropovich/Mstislav_Rostropovich_0001.jpg
# Saved face to /kaggle/working/processed_faces/Barry_Collier/Barry_Collier_0001.jpg
# Saved face to /kaggle/working/processed_faces/Matt_Herden/Matt_Herden_0001.jpg
# Saved face to /kaggle/working/processed_faces/Albert_Montanes/Albert_Montanes_0001.jpg
# Saved face to /kaggle/working/processed_faces/Daniel_Montgomery/Daniel_Montgomery_0001.jpg
# Saved face to /kaggle/working/processed_faces/William_Martin/William_Martin_0001.jpg
# Saved face to /kaggle/working/processed_faces/William_Martin/William_Martin_0002.jpg
# Number of processed face images: 13233
# Removed 0 duplicate images.
# Clean and structured dataset ready for training.
# Train images in /kaggle/working/data_split/train
# Validation images in /kaggle/working/data_split/val
